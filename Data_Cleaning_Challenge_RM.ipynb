# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import operator
# %matplotlib inline

data = pd.read_csv(r"WELLCOME_APCspend2013_forThinkful (1).csv",encoding='latin')

data['Journal title'] = data['Journal title'].str.replace('&', 'and')
data['Journal title'] = data['Journal title'].str.strip()
data['Journal title'] = data['Journal title'].str.upper()
data = data.drop(986)
data = data.reset_index(drop=True)

#Below are all of the edits to the Journal title column. 
#Multiple errors or typos could be fixed at the same time by filtering for a portion of the title and equating them all to the correct title. 
#However, most typos were unique and had to be solved by directly changing the individual title.

word = 'ACTA CRYSTALLOGRAPHICA SECTION D'
word_list = list(filter(lambda x: word in x, data['Journal title']))
#print(word_list)
n = 0
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = word_list[0]
    n+=1
    
word = 'ACTA CRYSTALLOGRAPHICA, SECTION D'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CRYSTALLOGRAPHY'
    n+=1
    
word = 'ACTA CRYSTALLOGRAPHY D'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CRYSTALLOGRAPHY'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'ACTA D':
        data['Journal title'][n] = 'ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CRYSTALLOGRAPHY'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'ACTA F':
        data['Journal title'][n] = 'ACTA CRYSTALLOGRAPHICA SECTION F: STRUCTURAL BIOLOGY AND CRYSTALLIZATION COMMUNICATIONS'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'ACTA NEUROPATHOL':
        data['Journal title'][n] = 'ACTA NEUROPATHOLOGICA'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'AMERICAN JNL EPIDEMIOLOGY':
        data['Journal title'][n] = 'AMERICAN JOURNAL OF EPIDEMIOLOGY'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'AMERICAN JOURNAL FOR CLINICAL NUTRITION':
        data['Journal title'][n] = 'AMERICAN JOURNAL OF CLINICAL NUTRITION'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'AM J BIOETH':
        data['Journal title'][n] = 'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'AM J TROP MED HYG':
        data['Journal title'][n] = 'AMERICAN JOURNAL OF TROPICAL MEDICINE AND HYGIENE'
    n+=1
    

n = 0
for x in data['Journal title']:
    if x == 'AMERICAN JOURNAL OF MEDICAL GENETICS PART A':
        data['Journal title'][n] = 'AMERICAN JOURNAL OF MEDICAL GENETICS'
    n+=1
    
    
n = 0
for x in data['Journal title']:
    if x == 'ANAL BIOANAL CHEM.':
        data['Journal title'][n] = 'ANALYTICAL BIOCHEMISTRY'
    n+=1
    
word = 'ANGEW'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'ANGEWANDTE CHEMIE INTERNATIONAL EDITION'
    n+=1
    
    
word = 'ENTS AND CHEMOTHERAPY'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'ANTIMICROBIAL AGENTS AND CHEMOTHERAPY'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('BEHAVIOUR', 'BEHAVIOR')

data['Journal title'] = data['Journal title'].str.replace('BEHAVIOURAL', 'BEHAVIORAL')

data['Journal title'] = data['Journal title'].str.replace('BEHAVIOURAL', 'BEHAVIORAL')

n = 0
for x in data['Journal title']:
    if x == 'BIOCHEM JOURNAL':
        data['Journal title'][n] = 'BIOCHEMICAL JOURNAL'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'BIOCHEM SOC TRANS':
        data['Journal title'][n] = 'BIOCHEMICAL SOCIETY TRANSACTIONS'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'BIOCHEMICAL JOURNALS':
        data['Journal title'][n] = 'BIOCHEMICAL JOURNAL'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('BIOOHYSICA', 'BIOPHYSICA')

word = '- MOLECULAR BASIS OF DISEASE'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE'
    n+=1
    
n = 0
for x in data['Journal title']:
    if x == 'BIOL OPEN':
        data['Journal title'][n] = 'BIOLOGY OPEN'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('BIOLOGICIAL', 'BIOLOGICAL')

data['Journal title'] = data['Journal title'].str.replace('BJOPHTHALMOL', 'BRITISH JOURNAL OF PHARMACOLOGY')

data['Journal title'] = data['Journal title'].str.replace('BJP', 'BRITISH JOURNAL OF PSYCHIATRY')

data['Journal title'] = data['Journal title'].str.replace('BMC  PUBLIC HEALTH', 'BMC PUBLIC HEALTH')

data['Journal title'] = data['Journal title'].str.replace('BMC GENOMICS.', 'BMC GENOMICS')

data['Journal title'] = data['Journal title'].str.replace('BMJ', 'BRITISH MEDICAL JOURNAL')

data['Journal title'] = data['Journal title'].str.replace('BMS GENOMICS', 'BMC GENOMICS')

data['Journal title'] = data['Journal title'].str.replace('BRITISH JOURNAL FOR THE HISTORY OF SCIENCE', 'BRITISH JOURNAL OF THE HISTORY OF SCIENCE')

data['Journal title'] = data['Journal title'].str.replace('BRITISH JOURNAL OF OPHTHALMOLOGY', 'BRITISH JOURNAL OF OPTHALMOLOGY')

data['Journal title'] = data['Journal title'].str.replace('BRT', 'BRITISH')

data['Journal title'] = data['Journal title'].str.replace('JNL', 'JOURNAL')

data['Journal title'] = data['Journal title'].str.replace('BRITSH', 'BRITISH')

data['Journal title'] = data['Journal title'].str.replace('CELL DEATH DIFFERENTIATION', 'CELL DEATH AND DIFFERENTIATION')

data['Journal title'] = data['Journal title'].str.replace('CHILD: CARE, HEALTH DEVELOPMENT', 'CHILD: CARE, HEATH AND DEVELOPMENT')

data['Journal title'] = data['Journal title'].str.replace('CLINICLA', 'CLINICAL')

data['Journal title'] = data['Journal title'].str.replace('CURRENT OPINION IN NEUROBIOLOGY', 'CURRENT OPINIONS IN NEUROBIOLOGY')

word = ' WORLD BIOETH'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'DEVELOPING WORLD BIOETHICS'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('DEVELOPMENT CELL', 'DEVELOPMENTAL CELL')

data['Journal title'] = data['Journal title'].str.replace('DEVELOPMENT SCIENCE', 'DEVELOPMENTAL SCIENCE')

data['Journal title'] = data['Journal title'].str.replace('EPIGENTICS', 'EPIGENETICS')

data['Journal title'] = data['Journal title'].str.replace('EUR J IMMUNOL', 'EUROPEAN JOURNAL OF IMMUNOLOGY')

data['Journal title'] = data['Journal title'].str.replace('EUROPEAN CHILD AND ADOLESCENT PSYCHIATTY', 'EUROPEAN CHILD AND ADOLESCENT PSYCHIATRY')

n = 0
for x in data['Journal title']:
    if x == 'FEBS J.':
        data['Journal title'][n] = 'FEBS JOURNAL'
    n+=1
    
word = 'EPIDEMOLOGY'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'EPIDEMIOLOGY'
    n+=1
    
word = 'HEPTOLOGY'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'HEPATOLOGY'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('HUM RESOUR HEALTH', 'HUMAN RESOURCES FOR HEALTH')

data['Journal title'] = data['Journal title'].str.replace('HUMAN MOL GENETICS ONLINE', 'HUMAN MOLECULAR GENETICS ONLINE')

data['Journal title'] = data['Journal title'].str.replace('IJTLD', 'INTERNATIONAL JOURNAL OF TUBERCULOSIS  AND LUNG DISEASE')

data['Journal title'] = data['Journal title'].str.replace('INT J EPIDEMIOL', 'INTERNATIONAL JOURNAL OF EPIDEMIOLOGY')

data['Journal title'] = data['Journal title'].str.replace('INT JOURNAL FOR PARASITOLOGY', 'INTERNATIONAL JOURNAL OF PARASITOLOGY')

data['Journal title'] = data['Journal title'].str.replace('INTERNATIONAL JOURNAL FOR PARASITOLOGY', 'INTERNATIONAL JOURNAL OF PARASITOLOGY')

word = 'JOURAL'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'JOURNAL'
    n+=1
    
word = 'INYERNATIONAL'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'INTERNATIONAL'
    n+=1
    
    
word = ' OD '
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = ' OF '
    n+=1
    
    
data['Journal title'] = data['Journal title'].str.replace('JOURNAL BIOLOGICAL CHEMISTRY', 'JOURNAL OF BIOLOGICAL CHEMISTRY')

word = 'BIOL CHEM'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'JOURNAL OF BIOLOGICAL CHEMISTRY'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('J CELL SCI.', 'JOURNAL OF CELL SCIENCE')

data['Journal title'] = data['Journal title'].str.replace('J CLIN MICROBIOL', 'JOURNAL OF CLINICAL MICROBIOLOGY')

data['Journal title'] = data['Journal title'].str.replace('J IMMUNOL', 'JOURNAL OF IMMUNOLOGY')

data['Journal title'] = data['Journal title'].str.replace('J INFECT DIS', 'JOURNAL OF INFECTIOUS DISEASES')

word = 'J MED CHEM'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'JOURNAL OF MEDICINAL CHEMISTRY'
    n+=1
    
    
data['Journal title'] = data['Journal title'].str.replace('J MOL BIOL', 'JOURNAL OF MOLECULAR BIOLOGY')

data['Journal title'] = data['Journal title'].str.replace('JAIDS JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES', 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES')

data['Journal title'] = data['Journal title'].str.replace('JOUNRAL OF CLINICAL MICROBIOLOGY', 'JOURNAL OF CLINICAL MICROBIOLOGY')

word = '(JAIDS)'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('JOURNAL OF AUTISM AND DEVELOPMENT DISORDERS', 'JOURNAL OF AUTISM AND DEVELOPMENTAL DISORDERS')

data['Journal title'] = data['Journal title'].str.replace('JOURNAL OF THE ROYAL SOCIETY, INTERFACE', 'JOURNAL OF THE ROYAL SOCIETY INTERFACE')

n = 0
for x in data['Journal title']:
    if x == 'JOURNAL OF VIROL':
        data['Journal title'][n] = 'JOURNAL OF VIROLOGY'
    n+=1


data['Journal title'] = data['Journal title'].str.replace('VISULAIZED', 'VISUALIZED')

    
word = 'JOURNAL OF VISUALIZED EXPER'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'JOURNAL OF VISUALIZED EXPERIMENTS'
    n+=1
    
    

data['Journal title'] = data['Journal title'].str.replace('MARTEN CHILD NUTR', 'MATERNAL AND CHILD NUTRITION')

data['Journal title'] = data['Journal title'].str.replace('MBIO', 'MICROBIOLOGY')

data['Journal title'] = data['Journal title'].str.replace('MCP (MOLECULAR AND CELLULAR PROTEOMICS)', 'MOLECULAR AND CELLULAR PROTEOMICS')

data['Journal title'] = data['Journal title'].str.replace('MICROBES INFECT', 'MICROBES AND INFECTION')

data['Journal title'] = data['Journal title'].str.replace('MOL BIO', 'MOLECULAR BIOLOGY')

data['Journal title'] = data['Journal title'].str.replace('MOL BIOL AND EVOLUTION', 'MOLECULAR BIOLOGY AND EVOLUTION')

data['Journal title'] = data['Journal title'].str.replace('NEPHROLOGY DIALYSIS TRANSPLANTATION', 'NEPHROLOGY DIALYSIS AND TRANSPLANTATION')

data['Journal title'] = data['Journal title'].str.replace('NEUROLMAGE', 'NEUROIMAGE')

data['Journal title'] = data['Journal title'].str.replace('NEUROPHYSIOLOGIA', 'NEUROPSYCHOLOGIA')

data['Journal title'] = data['Journal title'].str.replace('NUCLEIC ACID RESEARCH', 'NUCLEIC ACIDS RESEARCH')

data['Journal title'] = data['Journal title'].str.replace('PARASIT VECTORS.', 'PARASITES AND VECTORS')


word = 'PFLUGERS ARCHIV'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'PFLUGERS ARCHIVE'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('PHILOS TRANS R SOC LONDON B BIOL SCI', 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES')

data['Journal title'] = data['Journal title'].str.replace('PHILOSOPHICAL TRANSACTIONS B', 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES')

data['Journal title'] = data['Journal title'].str.replace('PLOS 1', 'PLOS ONE')

data['Journal title'] = data['Journal title'].str.replace('PLOS  ONE', 'PLOS ONE')

data['Journal title'] = data['Journal title'].str.replace('PLOS NEGECTED TROPICAL DISEASES', 'PLOS NEGLECTED TROPICAL DISEASES')

data['Journal title'] = data['Journal title'].str.replace('PLOS NTD', 'PLOS NEGLECTED TROPICAL DISEASES')

data['Journal title'] = data['Journal title'].str.replace('PLOSONE', 'PLOS ONE')

data['Journal title'] = data['Journal title'].str.replace('PLOS MEDICINE', 'PLOS MEDICINE JOURNAL')

word = 'PLOS MEDICINE'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'PLOS MEDICINE JOURNAL'
    n+=1


word = 'PNAS'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA'
    n+=1
    

data['Journal title'] = data['Journal title'].str.replace('PROC NATL ACAD SCI U S A.', 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA')

word = 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('PROCEDDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF USA', 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA')

data['Journal title'] = data['Journal title'].str.replace('PROCEEDINGS B', 'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES')

data['Journal title'] = data['Journal title'].str.replace('PROCEEDINGS OF ROYAL SOCIETY', 'PROCEEDINGS OF THE ROYAL SOCIETY')

    
data['Journal title'] = data['Journal title'].str.replace('PLOS', 'PUBLIC LIBRARY OF SCIENCE')

data['Journal title'] = data['Journal title'].str.replace('  ', ' ')

data['Journal title'] = data['Journal title'].str.replace('SCI REP', 'SCIENTIFIC REPORTS')

data['Journal title'] = data['Journal title'].str.replace('SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOL', 'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGY')

data['Journal title'] = data['Journal title'].str.replace('SEX TRANSM INFECT.', 'SEXUALLY TRANSMITTED INFECTIONS')

data['Journal title'] = data['Journal title'].str.replace('STUDIES IN HISTORY AND PHILOSOPHY OF SCIENCE PART C', 'STUDIES IN HISTORY AND PHILOSOPHY OF SCIENCE PART C: STUDIES IN HISTORY AND PHILOSOPHY OF BIOLOGICAL AND BIOMEDICAL SCIENCES')

data['Journal title'] = data['Journal title'].str.replace('THE AMERICAL JOURNAL OF HUMAN GENETICS', 'THE AMERICAN JOURNAL OF HUMAN GENETICS')

word = 'LANCET'
word_list = list(filter(lambda x: word in x, data['Journal title']))
n = 0
#print(word_list)
for x in data['Journal title']:
    if x in word_list:
        data['Journal title'][n] = 'THE LANCET NEUROLOGY'
    n+=1
    
data['Journal title'] = data['Journal title'].str.replace('THORAX', 'THORAX AN INTERNATIONAL JOURNAL FOR RESPIRATORY MEDICINE')

data['Journal title'] = data['Journal title'].str.replace('TRENDS IN NEUROSCIENCES', 'TRENDS IN NEUROSCIENCE')

data['Journal title'] = data['Journal title'].str.replace('TROP MED INT HEALTH', 'TROPICAL MEDICINE AND INTERNATIONAL HEALTH')

#Below is a dictionary that counts the appearance of each individual journal and then orders them by frequency.
#The top 5 are the selected and put into the 'top_list' list.
#A new dataframe (data2) is then created to house the relevent information after dropping the unwanted columns.

count_dict = {}
for x in data['Journal title']:
    if x in count_dict.keys():
        count_dict[x] += 1
    else:
        count_dict.update( {x : 1} )
sorted_x = sorted(count_dict.items(),reverse = True, key=lambda kv: kv[1])

top_list = []
for x in sorted_x[:5]:
    top_list.append(x[0])
    
data2 = data.drop(columns = ['PMID/PMCID', 'Publisher', 'Article title'])

#Below is the calculations for the mean, median, and standard deviation for the top 5 journals.
#In order to calculate them, the dollar sign had to be removed and then the data was converted to a float.
#From there, unusually high prices were removed.
#Finally, the three values for all 5 journals were calculated and then displayed next to the journal title.

num1data = data2.loc[(data2['Journal title'] == top_list[0])]
num1data = num1data.reset_index(drop=True)
n=0
for x in num1data.iloc[:,1]:
    num1data.iloc[n,1] = float(x[1:])
    n+=1
n=0
for y in num1data.iloc[:,1]:
    if y > 99999:
        num1data = num1data.drop(n)
    n+=1
num1mean = num1data.iloc[:,1].mean()
num1median = num1data.iloc[:,1].median()
num1std = num1data.iloc[:,1].std()

print('The mean, median, and standard deviation for {} is ${}, ${}, and ${}'.format(top_list[0], num1mean, num1median, num1std))

num1data = data2.loc[(data2['Journal title'] == top_list[1])]
num1data = num1data.reset_index(drop=True)
n=0
for x in num1data.iloc[:,1]:
    num1data.iloc[n,1] = float(x[1:])
    n+=1
n=0
for y in num1data.iloc[:,1]:
    if y > 99999:
        num1data = num1data.drop(n)
    n+=1
num1mean = num1data.iloc[:,1].mean()
num1median = num1data.iloc[:,1].median()
num1std = num1data.iloc[:,1].std()

print('The mean, median, and standard deviation for {} is ${}, ${}, and ${}'.format(top_list[1], num1mean, num1median, num1std))

num1data = data2.loc[(data2['Journal title'] == top_list[2])]
num1data = num1data.reset_index(drop=True)
n=0
for x in num1data.iloc[:,1]:
    num1data.iloc[n,1] = float(x[1:])
    n+=1
n=0
for y in num1data.iloc[:,1]:
    if y > 99999:
        num1data = num1data.drop(n)
    n+=1
num1mean = num1data.iloc[:,1].mean()
num1median = num1data.iloc[:,1].median()
num1std = num1data.iloc[:,1].std()

print('The mean, median, and standard deviation for {} is ${}, ${}, and ${}'.format(top_list[2], num1mean, num1median, num1std))

num1data = data2.loc[(data2['Journal title'] == top_list[3])]
num1data = num1data.reset_index(drop=True)
n=0
for x in num1data.iloc[:,1]:
    num1data.iloc[n,1] = float(x[1:])
    n+=1
n=0
for y in num1data.iloc[:,1]:
    if y > 99999:
        num1data = num1data.drop(n)
    n+=1
num1mean = num1data.iloc[:,1].mean()
num1median = num1data.iloc[:,1].median()
num1std = num1data.iloc[:,1].std()

print('The mean, median, and standard deviation for {} is ${}, ${}, and ${}'.format(top_list[3], num1mean, num1median, num1std))

num1data = data2.loc[(data2['Journal title'] == top_list[4])]
num1data = num1data.reset_index(drop=True)
n=0
for x in num1data.iloc[:,1]:
    num1data.iloc[n,1] = float(x[1:])
    n+=1
n=0
for y in num1data.iloc[:,1]:
    if y > 99999:
        num1data = num1data.drop(n)
    n+=1
num1mean = num1data.iloc[:,1].mean()
num1median = num1data.iloc[:,1].median()
num1std = num1data.iloc[:,1].std()

print('The mean, median, and standard deviation for {} is ${}, ${}, and ${}'.format(top_list[4], num1mean, num1median, num1std))
# Out:
# The mean, median, and standard deviation for PUBLIC LIBRARY OF SCIENCE ONE is $935.5772361809031, $896.99, and $194.65438505232936
# The mean, median, and standard deviation for JOURNAL OF BIOLOGICAL CHEMISTRY is $1388.865806451613, $1302.38, and $409.8643299624505
# The mean, median, and standard deviation for PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA is $772.9191666666668, $732.01, and $370.19193205976654
# The mean, median, and standard deviation for NEUROIMAGE is $2212.1812903225805, $2326.43, and $273.19324434963534
# The mean, median, and standard deviation for NUCLEIC ACIDS RESEARCH is $1162.344827586207, $852.0, and $442.15093381769765
